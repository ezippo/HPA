# %%
import sys
import os

# Absolute path to your module's directory
module_path = os.path.abspath('/localscratch/zippoema/git/HPA/src/')
if module_path not in sys.path:
    sys.path.insert(0, module_path)

import hpa.cluster as hpacl  # Now this should work
import hpa.util as hpau  # Now this should work

# %%
import numpy as np
from matplotlib import pyplot as plt
from tqdm import tqdm
import gsd.hoomd

# %%
path = '/localscratch/zippoema/mogon/mogon-nhr_lustre/project_condensate_ness/200-tdp43_CAL3/sim_200-tdp43-lcd_CAL3/'

# %%
tr = gsd.hoomd.open(path+'therm1_200-tdp43-lcd_CAL3_resize_end.gsd', mode='rb')
# Out:
# /localscratch/zippoema/lib/python_envs/hpa_env/lib/python3.11/site-packages/gsd/hoomd.py:1125: FutureWarning: The 'rb' mode is deprecated, use 'r'
#   gsdfileobj = fl.open(name=str(name),

# %%
for i in range(1,11):
    hpau.center_trajectory(path+f'therm{i}_200-tdp43-lcd_CAL3_resize_end.gsd', path+f'therm{i}_200-tdp43-lcd_CAL3_centered1.gsd')
    hpau.center_trajectory(path+f'therm{i}_200-tdp43-lcd_CAL3_centered1.gsd', path+f'therm{i}_200-tdp43-lcd_CAL3_centered.gsd')
    hpau.center_trajectory(path+f'therm{i}_200-tdp43-lcd_CAL3_centered.gsd', path+f'therm{i}_200-tdp43-lcd_CAL3_centered1.gsd')
    hpau.center_trajectory(path+f'therm{i}_200-tdp43-lcd_CAL3_centered1.gsd', path+f'therm{i}_200-tdp43-lcd_CAL3_centered.gsd')
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.10it/s]
